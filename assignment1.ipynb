# %%
# Taking student details
name = input("Enter student name: ")
student_class = input("Enter class: ")

# Taking marks of 5 subjects
sub1 = float(input("Enter marks of Subject 1: "))
sub2 = float(input("Enter marks of Subject 2: "))
sub3 = float(input("Enter marks of Subject 3: "))
sub4 = float(input("Enter marks of Subject 4: "))
sub5 = float(input("Enter marks of Subject 5: "))

# Calculating total and percentage
total = sub1 + sub2 + sub3 + sub4 + sub5
percentage = total / 5

# Displaying result
print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# ----- RESULT -----
# Student Name : abc
# Class : 11
# Total Marks : 458.0
# Percentage : 91.6 %

# %%
# Taking two strings
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Concatenating strings
new_string = str1 + " " + str2

print("\nConcatenated String:", new_string)

# Applying string methods
print("lower()      :", new_string.lower())
print("upper()      :", new_string.upper())
print("title()      :", new_string.title())
print("swapcase()   :", new_string.swapcase())
print("capitalize() :", new_string.capitalize())
print("casefold()   :", new_string.casefold())
print("center()     :", new_string.center(50, "*"))
print("count('a')   :", new_string.count('a'))
print("endswith()   :", new_string.endswith("a"))
print("find('a')    :", new_string.find('a'))
print("isalnum()    :", new_string.isalnum())
print("isdigit()    :", new_string.isdigit())
print("isnumeric()  :", new_string.isnumeric())
print("isspace()    :", new_string.isspace())
print("replace()    :", new_string.replace("a", "@"))
# Out:
# Concatenated String: python notebook
# lower()      : python notebook
# upper()      : PYTHON NOTEBOOK
# title()      : Python Notebook
# swapcase()   : PYTHON NOTEBOOK
# capitalize() : Python notebook
# casefold()   : python notebook
# center()     : *****************python notebook******************
# count('a')   : 0
# endswith()   : False
# find('a')    : -1
# isalnum()    : False
# isdigit()    : False
# isnumeric()  : False
# isspace()    : False
# replace()    : python notebook

# %%
# Assignment Operators Example

a = 10
print("Initial value of a =", a)

a += 5
print("After += 5 :", a)

a -= 3
print("After -= 3 :", a)

a *= 2
print("After *= 2 :", a)

a /= 4
print("After /= 4 :", a)

a %= 3
print("After %= 3 :", a)

a **= 2
print("After **= 2 :", a)

a //= 2
print("After //= 2 :", a)
# Out:
# Initial value of a = 10
# After += 5 : 15
# After -= 3 : 12
# After *= 2 : 24
# After /= 4 : 6.0
# After %= 3 : 0.0
# After **= 2 : 0.0
# After //= 2 : 0.0

# %%
# Taking student details
name = input("Enter student name: ")
student_class = input("Enter class: ")

# Taking marks
sub1 = float(input("Enter marks of Subject 1: "))
sub2 = float(input("Enter marks of Subject 2: "))
sub3 = float(input("Enter marks of Subject 3: "))
sub4 = float(input("Enter marks of Subject 4: "))
sub5 = float(input("Enter marks of Subject 5: "))

# Calculating total and percentage
total = sub1 + sub2 + sub3 + sub4 + sub5
percentage = total / 5

# Finding grade
if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

# Displaying result
print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
print("Grade :", grade)
# Out:
# ----- RESULT -----
# Student Name : abc
# Class : 11
# Total Marks : 416.0
# Percentage : 83.2 %
# Grade : A
