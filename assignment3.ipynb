# %%
# Dictionary Example

student = {
    "name": "Nitesh",
    "class": "BCA",
    "marks": 85
}

# Printing dictionary
print("Dictionary:", student)

# Accessing values
print("Name:", student["name"])

# Adding new item
student["grade"] = "A"

# Updating value
student["marks"] = 90

# Printing updated dictionary
print("Updated Dictionary:", student)

# Loop through dictionary
for key, value in student.items():
    print(key, ":", value)
# Out:
# Dictionary: {'name': 'Nitesh', 'class': 'BCA', 'marks': 85}
# Name: Nitesh
# Updated Dictionary: {'name': 'Nitesh', 'class': 'BCA', 'marks': 90, 'grade': 'A'}
# name : Nitesh
# class : BCA
# marks : 90
# grade : A

# %%
# Tuple Example

numbers = (10, 20, 30, 40, 50)

print("Tuple:", numbers)

# Accessing elements
print("First Element:", numbers[0])

# Length of tuple
print("Length:", len(numbers))

# Counting element
print("Count of 20:", numbers.count(20))

# Index of element
print("Index of 30:", numbers.index(30))
# Out:
# Tuple: (10, 20, 30, 40, 50)
# First Element: 10
# Length: 5
# Count of 20: 1
# Index of 30: 2

# %%
# Set Example

my_set = {1, 2, 3, 4, 5}

print("Set:", my_set)

# Adding element
my_set.add(6)

# Removing element
my_set.remove(3)

print("Updated Set:", my_set)

# Set operations
set2 = {4, 5, 6, 7}

print("Union:", my_set.union(set2))
print("Intersection:", my_set.intersection(set2))
# Out:
# Set: {1, 2, 3, 4, 5}
# Updated Set: {1, 2, 4, 5, 6}
# Union: {1, 2, 4, 5, 6, 7}
# Intersection: {4, 5, 6}

# %%
# Functions for basic math operations

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not allowed"

# Taking input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Calling functions
print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Addition = 63.0
# Subtraction = 27.0
# Multiplication = 810.0
# Division = 2.5

# %%
# Palindrome Number Program

num = int(input("Enter a number: "))

# Store original number
original_num = num

# Reverse the number
reverse_num = 0

while num > 0:
    digit = num % 10
    reverse_num = reverse_num * 10 + digit
    num = num // 10

# Check palindrome
if original_num == reverse_num:
    print(original_num, "is a Palindrome Number")
else:
    print(original_num, "is not a Palindrome Number")
# Out:
# 45 is not a Palindrome Number
